останки Сухэ-Батора, вождя монгольской социалистической революции 1921 года. Но, в отличие от других подобных мавзолеев, доступ к их телам был закрыт. Музей простоял до 2005 года, позже тела кремировали и перезахоронили в Алтан-Улгии, а здание снесли и соорудили на его месте мемориал в честь Чингисхана. Мавзолей Мао Цзэдуна, Китай. После смерти Мао Цзэдуна в 1976 году его тело подвергли бальзамированию, потом поместили в специальную усыпальницу, построенную в центральной части площади Тяньаньмэнь в Пекине, и дали ей название «Мемориальный комплекс председателя Мао». В отличие от других мавзолеев, этот мемориальный комплекс поражает своими размерами: его площадь — 57 тысяч квадратных метров, а территория разбита на пять больших залов. Тело вождя в хрустальном гробу расположено в Зале посетителей. Его всё еще можно посетить, но придется отстоять огромную очередь и пройти своеобразный фейс-контроль. Пускают в Зал только тех, кто одет прилично и аккуратно. Кымсусанский дворец Солнца, КНДР. Усыпальницей для северокорейских вождей в Пхеньяне служит Кымсусанский дворец Солнца, бывшая парадная резиденция Ким Ир Сена. Ее перестроили в огромный мемориальный комплекс. Тут находятся не только забальзамированные тела Ким Ир Сена и Ким Чен Ира, но и музей с их личными вещами, автомобилями и даже персональным бронированным вагоном. Мавзолей открыт для посетителей, но, как и в Китае, тут тоже придется пройти фейс- и дресс-контроль и обыск. Агостиньо Нето, первый президент Анголы, пытавшийся построить в стране коммунистический рай, умер в 1979 году. Тогда же его тело забальзамировали советские специалисты и отправили на родину, где уже началось строительство мавзолея, продлившееся 30 лет. В течение этого времени доступ к телу открывали раз в году. А в 1992 году по просьбе семьи тело все же похоронили на центральной площади столицы. Но строительство мемориального комплекса не остановили и открыли его в 2012 году. Сейчас он представляет собой футуристичное сооружение в стиле советского брутализма, чем-то напоминающее ракету. Сам мавзолей переквалифицировали в памятник независимости Анголы.'

# %% [markdown]
# Источники текстов: https://www.vokrugsveta.ru/articles/neuzheli-oni-letayut-3-pticy-tyazhelovesa-pokorivshie-vozdukh-id689613/, https://www.vokrugsveta.ru/article/243630/, https://www.vokrugsveta.ru/article/188139/ и т.д. Ключевые слова там выделены как тэги в конце статьи.

# %%
init_tags_1 = ['истории', 'зоология', 'наука', 'птицы']
init_tags_2 = ['монголия', 'форма', 'солдаты', 'армия', 'история костюма']
init_tags_3 = ['вегетарианство', 'животные', 'кулинария', 'овощи']
init_tags_4 = ['статуя свободы', 'нью-йорк','сша','франция','истории','путешествия']
init_tags_5 = ['история', 'реформация','европа','религия']
init_tags_6 = ['авто','волга','газ','ссср','истории','история']
init_tags_7 = ['местные жители','маяк','курильские острова','россия']
init_tags_8 = ['истории','история', 'фотоистория', 'мавзолей', 'сооружения', 'ХХ век', 'архитектура']

# %%
my_tags_1 = ['птицы', 'большие птицы', 'летающие птицы', 'орнитология', 'дрофа', 'андский кондор', 'аргентавис']
my_tags_2 = ['монголия', 'форма', 'военная форма', 'армия монголии', 'история костюма']
my_tags_3 = ['вегетарианство', 'веганство', 'животные', 'мифы', 'питание', 'стиль жизни']
my_tags_4 = ['статуя свободы', 'cша', 'франция', 'история создания', 'архитектура', 'эйфель']
my_tags_5 = ['история', 'реформация', 'протестантизм', 'лютер', 'религия', 'история христианства']
my_tags_6 = ['история', 'советские автомобили', 'газ', 'волга', 'москвич', 'запорожец', 'модели автомобилей', 'советская автопромышленность']
my_tags_7 = ['смотритель', 'маяк', 'курилы', 'остров', 'работа', 'жизнь']
my_tags_8 = ['история', 'мавзолей', 'архитектура', 'архитектура социализма', 'памятники']

# %% [markdown]
# Я выбрал этот сайт, потому что мне понравилось, что в статьях стоят тэги по тексту самой статьи, а не по рубрикам, что есть на сайте. Кроме того таких тэгов относительно много.
#
# Моя разметка в каких-то местах почти точно совпадает с разметкой сайта, иногда более расширенная. В случае первого текста довольно сильно расходится. Еще не очень хорошо, что в разметке с сайта встречается совершенно нерелевантное "лучшее". (Поэтому я превентивно убрал этот тэг из ключевых слов с сайта)
#
#
# В качестве эталонной разметки буду использовать пересечение наших разметок с исключением слова "лучшее".

# %%
# !pip install python-rake
# !pip install pymorphy2

# %%
from pymorphy2 import MorphAnalyzer
from pymorphy2.tokenizers import simple_word_tokenize
m = MorphAnalyzer()
def normalize_text(text):
    lemmas = []
    for t in simple_word_tokenize(text):
        lemmas.append(
            m.parse(t)[0].normal_form
        )
    return ' '.join(lemmas)

# %%
import RAKE
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('russian')
stop.append('который')
stop.append('это')
rake = RAKE.Rake(stop)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
texts = [text_1, text_2, text_3, text_4, text_5, text_6, text_7, text_8]
keywords_ = [set(init_tags_1 + my_tags_1), set(init_tags_2 + my_tags_2), set(init_tags_3 + my_tags_3),
            set(init_tags_4 + my_tags_4), set(init_tags_5 + my_tags_5), set(init_tags_6 + my_tags_6),
            set(init_tags_7 + my_tags_7), set(init_tags_8 + my_tags_8)]

# %% [markdown]
# # RAKE

# %%
for a in range(len(texts)):
  kw_list = rake.run(normalize_text(texts[a]), maxWords=3, minFrequency=2)
  print('======= text №', a+1, ' =======\n')
  print(kw_list[0:len(keywords_[a])],'\n', keywords_[a])
# Out:
# ======= text № 1  =======
#
# [('размах крыло', 4.533333333333333), ('кондор', 1.6666666666666667), ('воздух', 1.3333333333333333), ('вес', 1.0), ('земля', 1.0), ('лата', 1.0), ('глядеть', 1.0)]
#  {'большие птицы', 'птицы', 'андский кондор', 'зоология', 'аргентавис', 'летающие птицы', 'наука', 'дрофа', 'орнитология', 'истории'}
# ======= text № 2  =======
#
# [('монголия', 1.3333333333333333), ('похожий', 1.0)]
#  {'армия', 'солдаты', 'военная форма', 'монголия', 'армия монголии', 'форма', 'история костюма'}
# ======= text № 3  =======
#
# [('вегана', 1.8333333333333333), ('человек', 1.6666666666666667), ('фрукт', 1.6666666666666667), ('яйцо', 1.0), ('веганство', 1.0), ('правило', 1.0), ('следовать', 1.0), ('кстати', 1.0)]
#  {'животные', 'стиль жизни', 'мифы', 'веганство', 'вегетарианство', 'питание', 'кулинария', 'овощи'}
# ======= text № 4  =======
#
# ...

# %%
# !pip install summa
from summa import keywords

# %% [markdown]
# # TEXTRANK

# %%
for a in range(len(texts)):
  kw_list = keywords.keywords(normalize_text(texts[a]), language='russian', additional_stopwords=stop, scores=True)
  print('======= text №', a+1, ' =======\n')
  print(kw_list[0:len(keywords_[a])],'\n', keywords_[a])
# Out:
# ======= text № 1  =======
#
# 42
# [('птица', 0.287899526053768), ('дрофа', 0.1686757583746258), ('андский кондор', 0.16859490375224032), ('тяжёлый', 0.14451480578499062), ('лата', 0.1386419822103018), ('летать', 0.13100227370196307), ('белые', 0.12634309809482414), ('белый', 0.12634309809482414), ('аргентавис', 0.12313025198479285), ('палеонтолог', 0.11694478487633848)]
#  {'большие птицы', 'птицы', 'андский кондор', 'зоология', 'аргентавис', 'летающие птицы', 'наука', 'дрофа', 'орнитология', 'истории'}
# ======= text № 2  =======
#
# 23
# [('монгольский', 0.18949760851074884), ('металлический', 0.17478710015497934), ('воин армия', 0.16410697671083024), ('носить форма', 0.1613842159536058), ('советский', 0.16083930456961196), ('год', 0.14997551817417482), ('время', 0.14764260357980213)]
#  {'армия', 'солдаты', 'военная форма', 'монголия', 'армия монголии', 'форма', 'история костюма'}
# ======= text № 3  =======
#
# 61
# ...

# %% [markdown]
# # TFIDF

# %%
# !pip install wikipedia
import wikipedia
def download_wiki_texts(n, lang='ru'):
    wikipedia.set_lang(lang)
    pages = wikipedia.random(n)
    wiki_content_list = []
    for page_name in pages:
        try:
            page = wikipedia.page(page_name)
            wiki_content_list.append(page.content.replace('=', ''))
        except wikipedia.exceptions.WikipediaException:
            print("Skip %s" % page_name)
    return '\n'.join(wiki_content_list)

# %%
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

# %%
ref_corpus = []
for a in range(20):
  ref_corpus.append(normalize_text(download_wiki_texts(2)))
# Out:
# Skip Закалин, Александр Сергеевич
# /usr/local/lib/python3.7/dist-packages/wikipedia/wikipedia.py:389: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /usr/local/lib/python3.7/dist-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# Skip Гринцы
# Skip Иванов, Константин Васильевич

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv=CountVectorizer(max_df=0.85,stop_words=stop)
word_count_vector=cv.fit_transform(ref_corpus)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer= TfidfTransformer(smooth_idf=True, use_idf=True)
tfidf_transformer.fit(word_count_vector)

feature_names = cv.get_feature_names()
for a in range(len(texts)):
  tf_idf_vector=tfidf_transformer.transform(cv.transform([normalize_text(texts[a])]))
  sorted_items = sort_coo(tf_idf_vector.tocoo())
  kw_list = extract_topn_from_vector(feature_names, sorted_items,len(keywords_[a]))
  print('======= text №', a+1, ' =======\n')
  print(kw_list,'\n', keywords_[a])
# Out:
# ======= text № 1  =======
#
# {'птица': 0.645, 'тяжёлый': 0.194, 'лата': 0.17, 'просто': 0.129, 'попытка': 0.129, 'охота': 0.129, 'небо': 0.129, 'мочь': 0.129, 'вес': 0.129, 'белые': 0.129}
#  {'большие птицы', 'птицы', 'андский кондор', 'зоология', 'аргентавис', 'летающие птицы', 'наука', 'дрофа', 'орнитология', 'истории'}
# ======= text № 2  =======
#
# {'форма': 0.413, 'носить': 0.282, 'армия': 0.273, 'воин': 0.248, 'шлем': 0.188, 'флаг': 0.188, 'символ': 0.188}
#  {'армия', 'солдаты', 'военная форма', 'монголия', 'армия монголии', 'форма', 'история костюма'}
# ======= text № 3  =======
#
# {'миф': 0.57, 'животное': 0.25, 'большинство': 0.191, 'молоко': 0.171, 'человек': 0.159, 'среди': 0.126, 'член': 0.124, 'вместо': 0.124}
#  {'животные', 'стиль жизни', 'мифы', 'веганство', 'вегетарианство', 'питание', 'кулинария', 'овощи'}
# ======= text № 4  =======
#
# ...

# %% [markdown]
# # Морфологические шаблоны

# %% [markdown]
# В соответствии с теми ключевыми словами, которые я выделил, подходящими шаблонами будут: ADJ+NOUN (6 штук), NOUN+NOUN.GEN (8 штук). Остальные мои ключевые слова - существительные. Выведу топ-5 самых частотных сочетаний на каждый тип:

# %%
# !pip install spacy-udpipe

# %%
import spacy_udpipe
spacy_udpipe.download("ru")
from collections import Counter
# Out:
# Already downloaded a model for the 'ru' language

# %%
def split_text(text):
  sentences = []
  cur_sentence = ''
  for a in text:
    cur_sentence+=a
    if a in ['.','!', '?']:
      sentences.append(cur_sentence)
      cur_sentence = ''
  sentences.append(cur_sentence)
  return sentences

nlp = spacy_udpipe.load("ru")
i=1
for text in texts:
  scheme_AN = []
  scheme_NN = []
  text_s = split_text(text)
  for sentence in text_s:
    doc = nlp(sentence)
    for token in doc:
      if token.pos_ == 'ADJ':
        if token.head.pos_ == 'NOUN':
          scheme_AN.append(str(token)+' '+str(token.head))
      if token.pos_ == 'NOUN':
        if token.head.pos_ == 'NOUN':
          scheme_NN.append(str(token.head)+' '+str(token))
  freq_AN = Counter(scheme_AN)
  freq_NN = Counter(scheme_NN)
  print('====text №', i, '=========\n')
  print(freq_AN.most_common(5), '\n')
  print(freq_NN.most_common(5), '\n')
  i=i+1
# Out:
# ====text № 1 =========
#
# [('крупным животным', 1), ('тяжелые птицы', 1), ('летающие птицы', 1), ('степных районах', 1), ('крупную птицу', 1)]
#
# [('птицы птицы', 1), ('птицы тяжеловеса', 1), ('большинство птиц', 1), ('размерам весу', 1), ('Дрофа Дрофа', 1)]
#
# ====text № 2 =========
#
# [('почетного караула', 2), ('похожую форму', 2), ('монгольской роты', 1), ('великого завоевателя', 1), ('традиционные халаты', 1)]
#
# [('элементы символа', 2), ('Гутулы Гутулы', 2), ('Монголия Монголия', 1), ('Монголия доспехи', 1), ('Солдаты роты', 1)]
#
# ====text № 3 =========
#
# [('животного происхождения', 2), ('полноценный набор', 2), ('главных мифов', 1), ('Всемирный день', 1), ('модное поветрие', 1)]
#
# [('Миф Миф', 7), ('овощей фруктов', 3), ('образ жизни', 2), ('набор аминокислот', 2), ('мифов мифов', 1)]
#
# ====text № 4 =========
#
# [('нью-йоркскую бухту', 3), ('антирабовладельческого общества', 2), ('будущая статуя', 2), ('медных листов', 2), ('главная статуя', 1)]
#
# ...

# %% [markdown]
# # Применение морфологич.шаблонов к методам

# %% [markdown]
# Будем анализировать выдачу методов пословно, если будет Noun, Adj+Noun или Noun+Noun - оставляем, и так, пока не наберется эталонное число ключевых слов.

# %%
def apply_scheme(kw_list, n):
  kw_scheme = []
  for word in kw_list:
    doc = nlp(word[0])
    if len(doc) == 1:
      if doc[0].pos_ == 'NOUN':
        kw_scheme.append(word)
    if len(doc) == 2:
      if ((doc[0].pos_ == 'NOUN') and (doc[1].pos_ == 'NOUN')) or ((doc[0].pos_ == 'ADJ') and (doc[1].pos_ == 'NOUN')):
        kw_scheme.append(word) 
  return(kw_scheme[0:n-1])

# %% [markdown]
# Rake

# %%
for a in range(len(texts)):
  kw_list = rake.run(normalize_text(texts[a]), maxWords=3, minFrequency=2)
  print('======= text №', a+1, ' =======\n')
  print(apply_scheme(kw_list, len(keywords_[a])),'\n', keywords_[a])
# Out:
# ======= text № 1  =======
#
# [('кондор', 1.6666666666666667), ('воздух', 1.3333333333333333), ('вес', 1.0), ('земля', 1.0), ('лата', 1.0)]
#  {'большие птицы', 'птицы', 'андский кондор', 'зоология', 'аргентавис', 'летающие птицы', 'наука', 'дрофа', 'орнитология', 'истории'}
# ======= text № 2  =======
#
# [('монголия', 1.3333333333333333)]
#  {'армия', 'солдаты', 'военная форма', 'монголия', 'армия монголии', 'форма', 'история костюма'}
# ======= text № 3  =======
#
# [('человек', 1.6666666666666667), ('фрукт', 1.6666666666666667), ('яйцо', 1.0), ('веганство', 1.0), ('правило', 1.0)]
#  {'животные', 'стиль жизни', 'мифы', 'веганство', 'вегетарианство', 'питание', 'кулинария', 'овощи'}
# ======= text № 4  =======
#
# [('нью-йоркский бухта', 9.0), ('проект', 1.75), ('скульптор', 1.75), ('лабулэ', 1.6666666666666667), ('париж', 1.6666666666666667), ('ветер', 1.6666666666666667), ('америка', 1.5), ('родина', 1.3333333333333333), ('сша', 1.25)]
# ...

# %% [markdown]
# Text-Rank

# %%
for a in range(len(texts)):
  kw_list = keywords.keywords(normalize_text(texts[a]), language='russian', additional_stopwords=stop, scores=True)
  print('======= text №', a+1, ' =======\n')
  print(apply_scheme(kw_list, len(keywords_[a])),'\n', keywords_[a])
# Out:
# ======= text № 1  =======
#
# [('птица', 0.287899526053768), ('дрофа', 0.1686757583746258), ('андский кондор', 0.16859490375224032), ('лата', 0.1386419822103018), ('аргентавис', 0.12313025198479285), ('палеонтолог', 0.11694478487633848), ('крыло', 0.10098815020594548), ('оперение', 0.10047013798037219), ('падаль', 0.09334222430257762)]
#  {'большие птицы', 'птицы', 'андский кондор', 'зоология', 'аргентавис', 'летающие птицы', 'наука', 'дрофа', 'орнитология', 'истории'}
# ======= text № 2  =======
#
# [('воин армия', 0.16410697671083024), ('год', 0.14997551817417482), ('время', 0.14764260357980213), ('символ', 0.1406645277798033), ('монголия', 0.1375739992550524), ('монгол', 0.1375739992550524)]
#  {'армия', 'солдаты', 'военная форма', 'монголия', 'армия монголии', 'форма', 'история костюма'}
# ======= text № 3  =======
#
# ...

# %% [markdown]
# Для Tf-Idf не будем так делать, потому что там и так вся выдача из единичных слов

# %% [markdown]
# #  Анализ результатов

# %% [markdown]
# Изначально я указывал каждому методу выводить столько ключевых слов для каждого текста, сколько для него было слов в эталонной разметке. Мне кажется, это наиболее разумно, потому что максимальное число (11) отличается от минимального (7) уже в полтора раза, и непонятно, как выбрать оптимальное число, ведь сами по себе алгоритмы выдают число ключевых слов, исчисляемое десятками, и брать все из них - точно не круто. Из этого решения следует, что F1-score считать для каждого алгоритма бессмысленно, ведь precision=recall=(число совпавших ответов)/(эталонное число ответов).
#
# Кроме того, так как алгоритмы выдают результаты на препроцешенном тексте, не хочется запариваться и делать какой-то автоматический подсчет результатов. Более того, мы будем гибко подходить к оцениванию, например, я выделил в тексте про веганов ключевое слово "стиль жизни", а один из алгоритмов выбрал "образ жизни", и я засчитаю это за правильный ответ.

# %% [markdown]
# ![kw.png](data:image/png;base64,...)

# %% [markdown]
# Из данных результатов следует, что все алгоритмы справляются с разметкой ключевых слов очень плохо, но лучше всего делает это text-rank c морфологическим шаблоном. Применение морф. шаблона ожидаемо увеличивает результаты, ведь мы дополнительно выкидываем все слова, котоорые точно не подходят, соответственно повышается шанс, что на их месте окажутся другие - подходящие.

# %% [markdown]
# Но пока мы провели очень топорное сравнение. Давайте проведем еще и дополнительную проверку, посмотрим на результаты работы алгоритмов и зачтем все слова, которые могли бы быть ключевыми в этом тексте у какого-нибудь человеческого аннотатора.

# %% [markdown]
# ![kw.png](data:image/png;base64,...)

# %% [markdown]
# Так text-rank выглядит еще более предпочтительнее.

# %% [markdown]
# # Последние слова

# %% [markdown]
# Выделение ключевых слов с помощью алгоритмов довольно неточно. В качестве первой прикидки их можно использовать, но на деле, даже при супер-лояльном взгляде на выдачу, только 2 раза из 16 оказалось так, что больше половины слов подходят под звание "ключевых слов". То есть алгоритмы выдают очень много мусора.
#
#
# Алгоритмы неплохо ловят названия и всякие именованные сущности, которые часто повторяются в тексте, но такие статистические алгоритмы никогда не выдадут ключевое слово "социалистическая архитектура", если в тексте много говорилось про социалистические страны и описывались разные постройки. А такие семантические обобщения очень важны в ключевых словах. Из тех, что выделил я, подобным образом получены - военная форма, армия монголии, история костюма, стиль жизни, питание, история создания, история христианства, модели автомобилей, советская автопромышленность, архитектура социализма...
#
#
# Кроме того в текстах бывает, что в начале выделяется какая-то тема, а затем ее наименование уже не повторяют, углублясь в детали. Кажется, алгоритмы с радостью погружаются в эти детали, путаясь, тогда как человек сканирующим чтением, легче выцепляет подобные ключевые слова.
#
#
# В качестве предложений по улучшению моделей можно предложить более пристально рассматривать первые предложения абзацей, брать их с дополнительным весом, смотреть на их синтаксическую структуру и выцеплять главные члены предложения - субъект, объект. Давать дополнительный вес заголовкам.
